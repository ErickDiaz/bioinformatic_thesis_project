# %% [markdown]
# # Testing U-net testing
#
# Testing U-net with a few examples implemented with Keras
# Data set from data science bowl 2018

# %%
import numpy as np
import os
import sys
import random
import warnings

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import matplotlib.pyplot as plt

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Parameters

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'stage1_train/'
TEST_PATH = 'stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

print(X_train.shape)
print(Y_train.shape)
# Out:
# (670, 128, 128, 3)
# (670, 128, 128, 1)

# %%
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [03:00<00:00,  3.05it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:03<00:00, 21.49it/s]
# Done!

# %%
n_images = 5
fig, axes = plt.subplots(n_images,2,figsize=(10,10))
for i in range(n_images):
    ix = random.randint(0, len(train_ids))
    axes[i,0].imshow(X_train[ix])
    axes[i,1].imshow(np.squeeze(Y_train[ix]), cmap='gray')

fig = plt.gcf()
for ax in fig.axes:
    ax.axis('off')

plt.show()

# %% [markdown]
# ### IoU (Intersection of the union)
# The intersection of the union(IOU): Measure the total number of shared pixels after applying the masks
#
# \begin{equation*}
#   IOU = \frac{I_1 \cup I_2}{I_1 \cap I_2}
# \end{equation*}

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.array(np.mean(metric), dtype=np.float32)

def my_iou_metric(label, pred):
    metric_value = tf.py_func(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
def get_metrics_grafics(results):
    # 'val_loss', 'val_my_iou_metric', 'loss', 'my_iou_metric'
    plt.figure(figsize=(20,10))
    ## LOSS
    plt.subplot(221)
    plt.plot(results.history['loss'], label='Training loss')
    plt.plot(results.history['val_loss'], label='Validation loss')
    plt.legend(frameon=False)
    ## Intersection over union
    plt.subplot(222)
    plt.plot(results.history['my_iou_metric'], label='Training IoU')
    plt.plot(results.history['val_my_iou_metric'], label='Validation IoU')
    plt.legend(frameon=False)

    plt.show()

# %% [markdown]
# ## U-Net
#
# ![title](../../u-net-architecture.png)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(rate=0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(rate=0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(rate=0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(rate=0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(rate=0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(rate=0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(rate=0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(rate=0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(rate=0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[my_iou_metric])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128, 128, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 448         lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 32)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   9248        dropout_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 64)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   36928       dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 128)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  147584      dropout_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    295168      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 8, 8, 256)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 256)    590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 128)  131200      conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 16, 16, 128)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  147584      dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 64)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 32)   8224        conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_7[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 32)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 128, 128, 16) 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 16) 2320        dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 1)  17          conv2d_37[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Test Model with 100 images

# %%
limit = 100

checkpointer = ModelCheckpoint('model-unet-dsbowl2018-201905_100.h5', verbose=1, save_best_only=True)


results = model.fit(X_train[:limit], Y_train[:limit], validation_split=0.1, batch_size=5, epochs=40, 
                    callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /home/erick/anaconda3/envs/bioinformatic_thesis_gpu/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 90 samples, validate on 10 samples
# Epoch 1/40
# 90/90 [==============================] - 15s 172ms/step - loss: 0.4934 - my_iou_metric: 0.0109 - val_loss: 0.3484 - val_my_iou_metric: 0.0542
#
# Epoch 00001: val_loss improved from inf to 0.34838, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 2/40
# 90/90 [==============================] - 0s 4ms/step - loss: 0.2818 - my_iou_metric: 0.0737 - val_loss: 0.2344 - val_my_iou_metric: 0.1535
#
# Epoch 00002: val_loss improved from 0.34838 to 0.23441, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 3/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.2360 - my_iou_metric: 0.1362 - val_loss: 0.1924 - val_my_iou_metric: 0.1918
#
# Epoch 00003: val_loss improved from 0.23441 to 0.19238, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 4/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.2094 - my_iou_metric: 0.1892 - val_loss: 0.2036 - val_my_iou_metric: 0.2524
#
# Epoch 00004: val_loss did not improve from 0.19238
# Epoch 5/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.2195 - my_iou_metric: 0.1735 - val_loss: 0.1937 - val_my_iou_metric: 0.2852
#
# Epoch 00005: val_loss did not improve from 0.19238
# Epoch 6/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1841 - my_iou_metric: 0.2341 - val_loss: 0.1940 - val_my_iou_metric: 0.3066
#
# Epoch 00006: val_loss did not improve from 0.19238
# Epoch 7/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1607 - my_iou_metric: 0.2857 - val_loss: 0.1372 - val_my_iou_metric: 0.4137
#
# Epoch 00007: val_loss improved from 0.19238 to 0.13723, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 8/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1515 - my_iou_metric: 0.2972 - val_loss: 0.1293 - val_my_iou_metric: 0.4323
#
# Epoch 00008: val_loss improved from 0.13723 to 0.12929, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 9/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1379 - my_iou_metric: 0.3340 - val_loss: 0.1194 - val_my_iou_metric: 0.4482
#
# Epoch 00009: val_loss improved from 0.12929 to 0.11944, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 10/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1271 - my_iou_metric: 0.3791 - val_loss: 0.1132 - val_my_iou_metric: 0.5028
#
# Epoch 00010: val_loss improved from 0.11944 to 0.11319, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 11/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1374 - my_iou_metric: 0.3719 - val_loss: 0.1323 - val_my_iou_metric: 0.4576
#
# Epoch 00011: val_loss did not improve from 0.11319
# Epoch 12/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1486 - my_iou_metric: 0.3595 - val_loss: 0.1501 - val_my_iou_metric: 0.4857
#
# Epoch 00012: val_loss did not improve from 0.11319
# Epoch 13/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1390 - my_iou_metric: 0.3619 - val_loss: 0.1304 - val_my_iou_metric: 0.4176
#
# Epoch 00013: val_loss did not improve from 0.11319
# Epoch 14/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1295 - my_iou_metric: 0.3921 - val_loss: 0.1609 - val_my_iou_metric: 0.4155
#
# Epoch 00014: val_loss did not improve from 0.11319
# Epoch 15/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1292 - my_iou_metric: 0.3957 - val_loss: 0.1954 - val_my_iou_metric: 0.3307
#
# Epoch 00015: val_loss did not improve from 0.11319
# Epoch 16/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1305 - my_iou_metric: 0.4132 - val_loss: 0.1149 - val_my_iou_metric: 0.4987
#
# Epoch 00016: val_loss did not improve from 0.11319
# Epoch 17/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1190 - my_iou_metric: 0.4055 - val_loss: 0.1577 - val_my_iou_metric: 0.4023
#
# Epoch 00017: val_loss did not improve from 0.11319
# Epoch 18/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1225 - my_iou_metric: 0.4250 - val_loss: 0.1032 - val_my_iou_metric: 0.4980
#
# Epoch 00018: val_loss improved from 0.11319 to 0.10318, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 19/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1280 - my_iou_metric: 0.4059 - val_loss: 0.1275 - val_my_iou_metric: 0.4698
#
# Epoch 00019: val_loss did not improve from 0.10318
# Epoch 20/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1158 - my_iou_metric: 0.4272 - val_loss: 0.1058 - val_my_iou_metric: 0.5059
#
# Epoch 00020: val_loss did not improve from 0.10318
# Epoch 21/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1113 - my_iou_metric: 0.4286 - val_loss: 0.0972 - val_my_iou_metric: 0.5106
#
# Epoch 00021: val_loss improved from 0.10318 to 0.09719, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 22/40
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1093 - my_iou_metric: 0.4361 - val_loss: 0.1198 - val_my_iou_metric: 0.4378
#
# Epoch 00022: val_loss did not improve from 0.09719
# Epoch 23/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1137 - my_iou_metric: 0.4287 - val_loss: 0.1131 - val_my_iou_metric: 0.5031
#
# Epoch 00023: val_loss did not improve from 0.09719
# Epoch 24/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1065 - my_iou_metric: 0.4507 - val_loss: 0.0917 - val_my_iou_metric: 0.5436
#
# Epoch 00024: val_loss improved from 0.09719 to 0.09169, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 25/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0996 - my_iou_metric: 0.4505 - val_loss: 0.0949 - val_my_iou_metric: 0.5028
#
# Epoch 00025: val_loss did not improve from 0.09169
# Epoch 26/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1015 - my_iou_metric: 0.4452 - val_loss: 0.1114 - val_my_iou_metric: 0.4467
#
# Epoch 00026: val_loss did not improve from 0.09169
# Epoch 27/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0999 - my_iou_metric: 0.4512 - val_loss: 0.1045 - val_my_iou_metric: 0.4564
#
# Epoch 00027: val_loss did not improve from 0.09169
# Epoch 28/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0956 - my_iou_metric: 0.4599 - val_loss: 0.0931 - val_my_iou_metric: 0.4887
#
# Epoch 00028: val_loss did not improve from 0.09169
# Epoch 29/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0939 - my_iou_metric: 0.4632 - val_loss: 0.0921 - val_my_iou_metric: 0.4887
#
# Epoch 00029: val_loss did not improve from 0.09169
# Epoch 30/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0929 - my_iou_metric: 0.4803 - val_loss: 0.0984 - val_my_iou_metric: 0.4872
#
# Epoch 00030: val_loss did not improve from 0.09169
# Epoch 31/40
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0942 - my_iou_metric: 0.4677 - val_loss: 0.0906 - val_my_iou_metric: 0.5162
#
# Epoch 00031: val_loss improved from 0.09169 to 0.09055, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 32/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0936 - my_iou_metric: 0.4766 - val_loss: 0.0952 - val_my_iou_metric: 0.4778
#
# Epoch 00032: val_loss did not improve from 0.09055
# Epoch 33/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0885 - my_iou_metric: 0.4963 - val_loss: 0.1021 - val_my_iou_metric: 0.4802
#
# Epoch 00033: val_loss did not improve from 0.09055
# Epoch 34/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0907 - my_iou_metric: 0.4841 - val_loss: 0.0943 - val_my_iou_metric: 0.4979
#
# Epoch 00034: val_loss did not improve from 0.09055
# Epoch 35/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0859 - my_iou_metric: 0.4862 - val_loss: 0.0962 - val_my_iou_metric: 0.5014
#
# Epoch 00035: val_loss did not improve from 0.09055
# Epoch 36/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0883 - my_iou_metric: 0.4905 - val_loss: 0.0950 - val_my_iou_metric: 0.4926
# Epoch 00036: val_loss did not improve from 0.09055
# Epoch 37/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0861 - my_iou_metric: 0.5106 - val_loss: 0.0941 - val_my_iou_metric: 0.5087
#
# Epoch 00037: val_loss did not improve from 0.09055
# Epoch 38/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0886 - my_iou_metric: 0.4763 - val_loss: 0.0889 - val_my_iou_metric: 0.5215
#
# Epoch 00038: val_loss improved from 0.09055 to 0.08894, saving model to model-unet-dsbowl2018-201905_100.h5
# Epoch 39/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0849 - my_iou_metric: 0.4880 - val_loss: 0.0967 - val_my_iou_metric: 0.4864
#
# Epoch 00039: val_loss did not improve from 0.08894
# Epoch 40/40
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0824 - my_iou_metric: 0.5007 - val_loss: 0.0922 - val_my_iou_metric: 0.4949
#
# Epoch 00040: val_loss did not improve from 0.08894

# %%
get_metrics_grafics(results)

# %% [markdown]
# ### Test Model with 200 images

# %%
limit = 200

checkpointer = ModelCheckpoint('model-unet-dsbowl2018-201905_200.h5', verbose=1, save_best_only=True)


results = model.fit(X_train[:limit], Y_train[:limit], validation_split=0.1, batch_size=5, epochs=40, 
                    callbacks=[checkpointer])
# Out:
# Train on 180 samples, validate on 20 samples
# Epoch 1/40
# 180/180 [==============================] - 2s 10ms/step - loss: 0.4474 - my_iou_metric: 0.0374 - val_loss: 0.1868 - val_my_iou_metric: 0.1340
#
# Epoch 00001: val_loss improved from inf to 0.18676, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 2/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.2335 - my_iou_metric: 0.1725 - val_loss: 0.1415 - val_my_iou_metric: 0.1677
#
# Epoch 00002: val_loss improved from 0.18676 to 0.14154, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 3/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1757 - my_iou_metric: 0.2733 - val_loss: 0.1038 - val_my_iou_metric: 0.3431
#
# Epoch 00003: val_loss improved from 0.14154 to 0.10383, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 4/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1486 - my_iou_metric: 0.3328 - val_loss: 0.1184 - val_my_iou_metric: 0.3617
#
# Epoch 00004: val_loss did not improve from 0.10383
# Epoch 5/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1351 - my_iou_metric: 0.3799 - val_loss: 0.1179 - val_my_iou_metric: 0.3997
#
# Epoch 00005: val_loss did not improve from 0.10383
# Epoch 6/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1264 - my_iou_metric: 0.4042 - val_loss: 0.1170 - val_my_iou_metric: 0.4128
#
# Epoch 00006: val_loss did not improve from 0.10383
# Epoch 7/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1204 - my_iou_metric: 0.4051 - val_loss: 0.0918 - val_my_iou_metric: 0.4950
#
# Epoch 00007: val_loss improved from 0.10383 to 0.09183, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 8/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1183 - my_iou_metric: 0.4177 - val_loss: 0.0901 - val_my_iou_metric: 0.4405
#
# Epoch 00008: val_loss improved from 0.09183 to 0.09009, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 9/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1188 - my_iou_metric: 0.4141 - val_loss: 0.0914 - val_my_iou_metric: 0.4855
#
# Epoch 00009: val_loss did not improve from 0.09009
# Epoch 10/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1074 - my_iou_metric: 0.4534 - val_loss: 0.0761 - val_my_iou_metric: 0.5208
#
# Epoch 00010: val_loss improved from 0.09009 to 0.07608, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 11/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1029 - my_iou_metric: 0.4569 - val_loss: 0.0780 - val_my_iou_metric: 0.5436
#
# Epoch 00011: val_loss did not improve from 0.07608
# Epoch 12/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1052 - my_iou_metric: 0.4497 - val_loss: 0.0832 - val_my_iou_metric: 0.5042
#
# Epoch 00012: val_loss did not improve from 0.07608
# Epoch 13/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0997 - my_iou_metric: 0.4801 - val_loss: 0.0919 - val_my_iou_metric: 0.5308
#
# Epoch 00013: val_loss did not improve from 0.07608
# Epoch 14/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0985 - my_iou_metric: 0.4763 - val_loss: 0.0760 - val_my_iou_metric: 0.5516
#
# Epoch 00014: val_loss improved from 0.07608 to 0.07602, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 15/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0930 - my_iou_metric: 0.4939 - val_loss: 0.0745 - val_my_iou_metric: 0.5534
#
# Epoch 00015: val_loss improved from 0.07602 to 0.07450, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 16/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0940 - my_iou_metric: 0.4868 - val_loss: 0.0715 - val_my_iou_metric: 0.5684
#
# Epoch 00016: val_loss improved from 0.07450 to 0.07147, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 17/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0930 - my_iou_metric: 0.4878 - val_loss: 0.0898 - val_my_iou_metric: 0.4545
#
# Epoch 00017: val_loss did not improve from 0.07147
# Epoch 18/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.1012 - my_iou_metric: 0.4771 - val_loss: 0.0711 - val_my_iou_metric: 0.5364
#
# Epoch 00018: val_loss improved from 0.07147 to 0.07109, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 19/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0954 - my_iou_metric: 0.4887 - val_loss: 0.0709 - val_my_iou_metric: 0.5613
#
# Epoch 00019: val_loss improved from 0.07109 to 0.07088, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 20/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0899 - my_iou_metric: 0.4982 - val_loss: 0.0768 - val_my_iou_metric: 0.5418
#
# Epoch 00020: val_loss did not improve from 0.07088
# Epoch 21/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0885 - my_iou_metric: 0.5013 - val_loss: 0.0679 - val_my_iou_metric: 0.5812
#
# Epoch 00021: val_loss improved from 0.07088 to 0.06790, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 22/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0883 - my_iou_metric: 0.4948 - val_loss: 0.0656 - val_my_iou_metric: 0.5648
#
# Epoch 00022: val_loss improved from 0.06790 to 0.06557, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 23/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0860 - my_iou_metric: 0.5131 - val_loss: 0.0695 - val_my_iou_metric: 0.5540
#
# Epoch 00023: val_loss did not improve from 0.06557
# Epoch 24/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0855 - my_iou_metric: 0.5169 - val_loss: 0.0681 - val_my_iou_metric: 0.5547
#
# Epoch 00024: val_loss did not improve from 0.06557
# Epoch 25/40
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0847 - my_iou_metric: 0.5239 - val_loss: 0.0691 - val_my_iou_metric: 0.5777
#
# Epoch 00025: val_loss did not improve from 0.06557
# Epoch 26/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0818 - my_iou_metric: 0.5124 - val_loss: 0.0698 - val_my_iou_metric: 0.5664
#
# Epoch 00026: val_loss did not improve from 0.06557
# Epoch 27/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0850 - my_iou_metric: 0.5079 - val_loss: 0.0768 - val_my_iou_metric: 0.5523
#
# Epoch 00027: val_loss did not improve from 0.06557
# Epoch 28/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0880 - my_iou_metric: 0.5071 - val_loss: 0.0657 - val_my_iou_metric: 0.5639
#
# Epoch 00028: val_loss did not improve from 0.06557
# Epoch 29/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0850 - my_iou_metric: 0.5192 - val_loss: 0.0676 - val_my_iou_metric: 0.5464
#
# Epoch 00029: val_loss did not improve from 0.06557
# Epoch 30/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0837 - my_iou_metric: 0.5225 - val_loss: 0.0715 - val_my_iou_metric: 0.5678
#
# Epoch 00030: val_loss did not improve from 0.06557
# Epoch 31/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0802 - my_iou_metric: 0.5374 - val_loss: 0.0690 - val_my_iou_metric: 0.5491
#
# Epoch 00031: val_loss did not improve from 0.06557
# Epoch 32/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0801 - my_iou_metric: 0.5320 - val_loss: 0.0739 - val_my_iou_metric: 0.5684
#
# Epoch 00032: val_loss did not improve from 0.06557
# Epoch 33/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0876 - my_iou_metric: 0.5111 - val_loss: 0.0699 - val_my_iou_metric: 0.5785
#
# Epoch 00033: val_loss did not improve from 0.06557
# Epoch 34/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0888 - my_iou_metric: 0.4977 - val_loss: 0.0665 - val_my_iou_metric: 0.5312
#
# Epoch 00034: val_loss did not improve from 0.06557
# Epoch 35/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0830 - my_iou_metric: 0.5257 - val_loss: 0.0659 - val_my_iou_metric: 0.5787
#
# Epoch 00035: val_loss did not improve from 0.06557
# Epoch 36/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0811 - my_iou_metric: 0.5171 - val_loss: 0.0706 - val_my_iou_metric: 0.5686
#
# Epoch 00036: val_loss did not improve from 0.06557
# Epoch 37/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0783 - my_iou_metric: 0.5421 - val_loss: 0.0628 - val_my_iou_metric: 0.5829
#
# Epoch 00037: val_loss improved from 0.06557 to 0.06280, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 38/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0765 - my_iou_metric: 0.5514 - val_loss: 0.0700 - val_my_iou_metric: 0.5756
#
# Epoch 00038: val_loss did not improve from 0.06280
# Epoch 39/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0752 - my_iou_metric: 0.5653 - val_loss: 0.0627 - val_my_iou_metric: 0.6039
#
# Epoch 00039: val_loss improved from 0.06280 to 0.06265, saving model to model-unet-dsbowl2018-201905_200.h5
# Epoch 40/40
# 180/180 [==============================] - 1s 3ms/step - loss: 0.0737 - my_iou_metric: 0.5636 - val_loss: 0.0655 - val_my_iou_metric: 0.5860
#
# Epoch 00040: val_loss did not improve from 0.06265

# %%
get_metrics_grafics(results)

# %% [markdown]
# ### Test Model with 300 images

# %%
limit = 300

checkpointer = ModelCheckpoint('model-unet-dsbowl2018-201905_300.h5', verbose=1, save_best_only=True)


results = model.fit(X_train[:limit], Y_train[:limit], validation_split=0.1, batch_size=5, epochs=40, 
                    callbacks=[checkpointer])
# Out:
# Train on 270 samples, validate on 30 samples
# Epoch 1/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0746 - my_iou_metric: 0.5695 - val_loss: 0.0793 - val_my_iou_metric: 0.5771
#
# Epoch 00001: val_loss improved from inf to 0.07927, saving model to model-unet-dsbowl2018-201905_300.h5
# Epoch 2/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0716 - my_iou_metric: 0.5704 - val_loss: 0.0774 - val_my_iou_metric: 0.6042
#
# Epoch 00002: val_loss improved from 0.07927 to 0.07739, saving model to model-unet-dsbowl2018-201905_300.h5
# Epoch 3/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0606 - my_iou_metric: 0.6041 - val_loss: 0.0778 - val_my_iou_metric: 0.6069
#
# Epoch 00003: val_loss did not improve from 0.07739
# Epoch 4/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0585 - my_iou_metric: 0.6203 - val_loss: 0.0761 - val_my_iou_metric: 0.6039
#
# Epoch 00004: val_loss improved from 0.07739 to 0.07615, saving model to model-unet-dsbowl2018-201905_300.h5
# Epoch 5/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0547 - my_iou_metric: 0.6190 - val_loss: 0.0770 - val_my_iou_metric: 0.6059
#
# Epoch 00005: val_loss did not improve from 0.07615
# Epoch 6/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0519 - my_iou_metric: 0.6382 - val_loss: 0.0847 - val_my_iou_metric: 0.5713
#
# Epoch 00006: val_loss did not improve from 0.07615
# Epoch 7/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0512 - my_iou_metric: 0.6457 - val_loss: 0.0831 - val_my_iou_metric: 0.5889
#
# Epoch 00007: val_loss did not improve from 0.07615
# Epoch 8/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0488 - my_iou_metric: 0.6503 - val_loss: 0.0795 - val_my_iou_metric: 0.5987
#
# Epoch 00008: val_loss did not improve from 0.07615
# Epoch 9/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0466 - my_iou_metric: 0.6652 - val_loss: 0.0806 - val_my_iou_metric: 0.6292
#
# Epoch 00009: val_loss did not improve from 0.07615
# Epoch 10/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0449 - my_iou_metric: 0.6740 - val_loss: 0.0795 - val_my_iou_metric: 0.6157
#
# Epoch 00010: val_loss did not improve from 0.07615
# Epoch 11/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0433 - my_iou_metric: 0.6860 - val_loss: 0.0802 - val_my_iou_metric: 0.5983
#
# Epoch 00011: val_loss did not improve from 0.07615
# Epoch 12/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0448 - my_iou_metric: 0.6826 - val_loss: 0.0810 - val_my_iou_metric: 0.6117
#
# Epoch 00012: val_loss did not improve from 0.07615
# Epoch 13/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0438 - my_iou_metric: 0.6815 - val_loss: 0.0851 - val_my_iou_metric: 0.6174
#
# Epoch 00013: val_loss did not improve from 0.07615
# Epoch 14/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0428 - my_iou_metric: 0.6854 - val_loss: 0.0896 - val_my_iou_metric: 0.6120
#
# Epoch 00014: val_loss did not improve from 0.07615
# Epoch 15/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0429 - my_iou_metric: 0.6843 - val_loss: 0.0861 - val_my_iou_metric: 0.5960
#
# Epoch 00015: val_loss did not improve from 0.07615
# Epoch 16/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0405 - my_iou_metric: 0.7113 - val_loss: 0.0847 - val_my_iou_metric: 0.6088
#
# Epoch 00016: val_loss did not improve from 0.07615
# Epoch 17/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0428 - my_iou_metric: 0.6948 - val_loss: 0.0864 - val_my_iou_metric: 0.5978
#
# Epoch 00017: val_loss did not improve from 0.07615
# Epoch 18/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0487 - my_iou_metric: 0.6616 - val_loss: 0.0867 - val_my_iou_metric: 0.5954
#
# Epoch 00018: val_loss did not improve from 0.07615
# Epoch 19/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0430 - my_iou_metric: 0.6887 - val_loss: 0.0824 - val_my_iou_metric: 0.6119
#
# Epoch 00019: val_loss did not improve from 0.07615
# Epoch 20/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0420 - my_iou_metric: 0.6835 - val_loss: 0.0851 - val_my_iou_metric: 0.6196
#
# Epoch 00020: val_loss did not improve from 0.07615
# Epoch 21/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0394 - my_iou_metric: 0.7137 - val_loss: 0.0808 - val_my_iou_metric: 0.6219
#
# Epoch 00021: val_loss did not improve from 0.07615
# Epoch 22/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0389 - my_iou_metric: 0.7144 - val_loss: 0.0848 - val_my_iou_metric: 0.6212
#
# Epoch 00022: val_loss did not improve from 0.07615
# Epoch 23/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0388 - my_iou_metric: 0.7144 - val_loss: 0.0839 - val_my_iou_metric: 0.6291
#
# Epoch 00023: val_loss did not improve from 0.07615
# Epoch 24/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0375 - my_iou_metric: 0.7178 - val_loss: 0.0891 - val_my_iou_metric: 0.6212
#
# Epoch 00024: val_loss did not improve from 0.07615
# Epoch 25/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0369 - my_iou_metric: 0.7298 - val_loss: 0.0866 - val_my_iou_metric: 0.6181
#
# Epoch 00025: val_loss did not improve from 0.07615
# Epoch 26/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0361 - my_iou_metric: 0.7337 - val_loss: 0.0882 - val_my_iou_metric: 0.6118
#
# Epoch 00026: val_loss did not improve from 0.07615
# Epoch 27/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0359 - my_iou_metric: 0.7328 - val_loss: 0.0893 - val_my_iou_metric: 0.6198
#
# Epoch 00027: val_loss did not improve from 0.07615
# Epoch 28/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0356 - my_iou_metric: 0.7381 - val_loss: 0.0902 - val_my_iou_metric: 0.6253
#
# Epoch 00028: val_loss did not improve from 0.07615
# Epoch 29/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0378 - my_iou_metric: 0.7214 - val_loss: 0.0877 - val_my_iou_metric: 0.5897
#
# Epoch 00029: val_loss did not improve from 0.07615
# Epoch 30/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0366 - my_iou_metric: 0.7294 - val_loss: 0.0888 - val_my_iou_metric: 0.6099
#
# Epoch 00030: val_loss did not improve from 0.07615
# Epoch 31/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0346 - my_iou_metric: 0.7443 - val_loss: 0.0890 - val_my_iou_metric: 0.6300
#
# Epoch 00031: val_loss did not improve from 0.07615
# Epoch 32/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0345 - my_iou_metric: 0.7499 - val_loss: 0.0938 - val_my_iou_metric: 0.6130
#
# Epoch 00032: val_loss did not improve from 0.07615
# Epoch 33/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0352 - my_iou_metric: 0.7423 - val_loss: 0.0884 - val_my_iou_metric: 0.6195
#
# Epoch 00033: val_loss did not improve from 0.07615
# Epoch 34/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0346 - my_iou_metric: 0.7479 - val_loss: 0.0900 - val_my_iou_metric: 0.6123
#
# Epoch 00034: val_loss did not improve from 0.07615
# Epoch 35/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0342 - my_iou_metric: 0.7429 - val_loss: 0.0898 - val_my_iou_metric: 0.6090
#
# Epoch 00035: val_loss did not improve from 0.07615
# Epoch 36/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0345 - my_iou_metric: 0.7469 - val_loss: 0.0916 - val_my_iou_metric: 0.6124
#
# Epoch 00036: val_loss did not improve from 0.07615
# Epoch 37/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0337 - my_iou_metric: 0.7507 - val_loss: 0.0937 - val_my_iou_metric: 0.6222
#
# Epoch 00037: val_loss did not improve from 0.07615
# Epoch 38/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0332 - my_iou_metric: 0.7564 - val_loss: 0.0931 - val_my_iou_metric: 0.6102
#
# Epoch 00038: val_loss did not improve from 0.07615
# Epoch 39/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0332 - my_iou_metric: 0.7563 - val_loss: 0.0948 - val_my_iou_metric: 0.6202
#
# Epoch 00039: val_loss did not improve from 0.07615
# Epoch 40/40
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0326 - my_iou_metric: 0.7558 - val_loss: 0.0926 - val_my_iou_metric: 0.5967
#
# Epoch 00040: val_loss did not improve from 0.07615

# %% [markdown]
# ## Predictions

# %%
# Predict on train, val and test
#model = load_model('model-unet-dsbowl2018-201905_100.h5', custom_objects={'mean_iou': mean_iou})
model = load_model('model-unet-dsbowl2018-201905_100.h5', custom_objects={'my_iou_metric': my_iou_metric})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 1s 1ms/step
# 67/67 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 1ms/step

# %% [markdown]
# ### IMAGE |  MASK | PREDICTION

# %%
n_images = 10

fig, axes = plt.subplots(n_images,3,figsize=(15,15))

for i in range(n_images):
    ix = random.randint(0, len(preds_train_t-1))
    axes[i,0].imshow(X_train[ix])
    axes[i,1].imshow(np.squeeze(Y_train[ix]), cmap='gray')
    axes[i,2].imshow(np.squeeze(preds_train_t[ix]), cmap='gray')

fig = plt.gcf()
for ax in fig.axes:
    ax.axis('off')

plt.show()

# %%
y_true_in = Y_train[10]
y_pred_in = preds_train_t[10]

labels = label(y_true_in > 0.5)
y_pred = label(y_pred_in > 0.5)

true_objects = len(np.unique(labels))
pred_objects = len(np.unique(y_pred))

print(true_objects)
print(pred_objects)

intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]
print(intersection)
# Out:
# 31
# 26
# [[1.25e+04 1.10e+01 0.00e+00 7.50e+01 3.00e+00 4.10e+01 7.00e+00 1.40e+01
#   1.50e+01 3.00e+01 2.10e+01 9.00e+00 3.90e+01 3.20e+01 3.30e+01 1.60e+01
#   2.30e+01 2.00e+00 1.50e+01 5.00e+00 0.00e+00 1.00e+01 1.00e+01 1.00e+00
#   4.00e+00 1.20e+01]
#  [1.50e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [2.20e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 5.80e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [2.40e+01 0.00e+00 9.60e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [5.00e+00 0.00e+00 0.00e+00 3.39e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [7.00e+00 0.00e+00 0.00e+00 0.00e+00 1.13e+02 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [1.10e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.73e+02 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 9.30e+01 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [1.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.12e+02 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 6.00e+01
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [3.00e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   2.53e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 1.11e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 8.80e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 7.10e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [1.60e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 2.71e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 8.80e+01 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [1.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.30e+02 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [2.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.07e+02
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.26e+02 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 6.30e+01 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   7.10e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [3.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 1.00e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 1.22e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [1.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 1.24e+02 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [3.30e+01 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.34e+02 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [2.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 2.70e+01 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.20e+02 0.00e+00
#   0.00e+00 0.00e+00]
#  [7.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 2.50e+01
#   0.00e+00 0.00e+00]
#  [2.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   1.13e+02 0.00e+00]
#  [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00
#   0.00e+00 8.60e+01]]

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.array(np.mean(metric), dtype=np.float32)

def my_iou_metric(label, pred):
    metric_value = tf.py_func(iou_metric_batch, [label, pred], tf.float32)
    return metric_value
